# %% [markdown]
# <a href="https://colab.research.google.com/github/Random0Kid0Kaushik/ATA/blob/main/week4/3.fine-tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fine-tuning
#
# Another widely used transfer learning technique is _fine-tuning_.
# Fine-tuning involves unfreezing a few of the top layers
# of a frozen model base used for feature extraction, and jointly training both the newly added part of the model (in our case, the
# fully-connected classifier) and these unfrozen top layers. This is called "fine-tuning" because it slightly adjusts the more abstract
# representations of the model being reused, in order to make them more relevant for the problem at hand.
#
# ![fine-tuning VGG16](https://nyp-aicourse.s3.ap-southeast-1.amazonaws.com/it3103/resources/vgg16_fine_tuning.png)

# %%
import os
import keras
import keras.applications

# %% [markdown]
# It was necessary to freeze the convolution base of VGG16 in order to be able to train a randomly initialized
# classifier on top. For the same reason, it is only possible to fine-tune the top layers of the convolutional base once the classifier on
# top has already been trained. If the classified wasn't already trained, then the error signal propagating through the network during
# training would be too large, and the representations previously learned by the layers being fine-tuned would be destroyed. Thus the steps
# for fine-tuning a network are as follow:
#
# 1. Add your custom network on top of an already trained base network.
# 2. Freeze the base network.
# 3. Train the part you added.
# 4. Unfreeze some layers in the base network.
# 5. Jointly train both these layers and the part you added.

# %%
img_height, img_width = 128, 128

# Load the pre-trained model
base_model = keras.applications.VGG16(input_shape=(img_height, img_width) + (3,),
                                         include_top=False,
                                         weights='imagenet')

preprocess_input_fn = keras.applications.vgg16.preprocess_input

# freeze the base layer
base_model.trainable = False

# Add input layer
inputs = keras.layers.Input(shape=(img_height, img_width, 3))
# Add preprocessing layer
x = preprocess_input_fn(inputs)
# Add the base, set training to false to freeze the convolutional base
x = base_model(x)
# Add our classification head
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(rate=0.5)(x)
x = keras.layers.Dense(units=512, activation="relu")(x)
x = keras.layers.Dropout(rate=0.5)(x)
outputs = keras.layers.Dense(units=1, activation="sigmoid")(x)

model = keras.models.Model(inputs=[inputs], outputs=[outputs])

base_learning_rate = 0.001

model.compile(loss="binary_crossentropy",
                  optimizer=keras.optimizers.Adam(learning_rate=base_learning_rate),
                  metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Let's confirm all the layers of convolutional base are frozen.

# %%
for layer in base_model.layers:
    print(layer.name, layer.trainable)
# Out:
# input_layer False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 False
# block5_conv2 False
# block5_conv3 False
# block5_pool False

# %% [markdown]
# Let's print out the model summary and see how many trainable weights. We can see that we only 263,169 trainable weights (parameters), coming from the classification head that put on top of the convolutional base. (For comparison, a VGG16 has total of 14,714,688 weights).

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 128, 128,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 4, 4, 512) │ 14,714,688 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        513 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,977,857 (57.14 MB)
#  Trainable params: 263,169 (1.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## Creating Datasets
#
# We will setup our training and validation dataset as we did in earlier exercise.

# %%
dataset_URL = 'https://nyp-aicourse.s3-ap-southeast-1.amazonaws.com/datasets/cats_and_dogs_subset.tar.gz'
path_to_zip = keras.utils.get_file('cats_and_dogs_subset.tar.gz', origin=dataset_URL, extract=True, cache_dir='.')
dataset_dir = os.path.join(os.path.dirname(path_to_zip), "cats_and_dogs_subset_extracted/cats_and_dogs_subset")
# Out:
# Downloading data from https://nyp-aicourse.s3-ap-southeast-1.amazonaws.com/datasets/cats_and_dogs_subset.tar.gz
# 67041740/67041740 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
batch_size = 32
image_size = (img_height, img_width)

train_ds = keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='binary'
)
val_ds = keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='binary'
)
# Out:
# Found 3000 files belonging to 2 classes.
# Using 2400 files for training.
# Found 3000 files belonging to 2 classes.
# Using 600 files for validation.

# %% [markdown]
# ## Train the classification head
#
# We will go ahead and train our classification head.

# %%
# create model checkpoint callback to save the best model checkpoint
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath="best_checkpoint.weights.h5",
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

model.fit(train_ds, validation_data=val_ds,
          epochs=30, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_19']
# Received: inputs=Tensor(shape=(None, 128, 128, 3))
#   warnings.warn(msg)
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.8007 - loss: 2.6376 - val_accuracy: 0.9350 - val_loss: 0.4813
# Epoch 2/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.9001 - loss: 1.1969 - val_accuracy: 0.9367 - val_loss: 0.3678
# Epoch 3/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.9192 - loss: 0.6872 - val_accuracy: 0.9483 - val_loss: 0.2928
# Epoch 4/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.9255 - loss: 0.5538 - val_accuracy: 0.9483 - val_loss: 0.2839
# Epoch 5/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.9285 - loss: 0.4610 - val_accuracy: 0.9433 - val_loss: 0.2552
# Epoch 6/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.9372 - loss: 0.3860 - val_accuracy: 0.9483 - val_loss: 0.1818
# Epoch 7/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.9333 - loss: 0.2970 - val_accuracy: 0.9467 - val_loss: 0.1719
# Epoch 8/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9406 - loss: 0.2329 - val_accuracy: 0.9450 - val_loss: 0.1473
# Epoch 9/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9296 - loss: 0.2248 - val_accuracy: 0.9450 - val_loss: 0.1449
# Epoch 10/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.9425 - loss: 0.1985 - val_accuracy: 0.9283 - val_loss: 0.1765
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.9476 - loss: 0.1941 - val_accuracy: 0.9450 - val_loss: 0.1430
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9469 - loss: 0.1695 - val_accuracy: 0.9450 - val_loss: 0.1499
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9333 - loss: 0.1681 - val_accuracy: 0.9483 - val_loss: 0.1361
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9485 - loss: 0.1401 - val_accuracy: 0.9383 - val_loss: 0.1603
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9515 - loss: 0.1277 - val_accuracy: 0.9483 - val_loss: 0.1349
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9656 - loss: 0.1028 - val_accuracy: 0.9483 - val_loss: 0.1403
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.9534 - loss: 0.1454 - val_accuracy: 0.9500 - val_loss: 0.1350
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9495 - loss: 0.1374 - val_accuracy: 0.9450 - val_loss: 0.1324
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9552 - loss: 0.1205 - val_accuracy: 0.9450 - val_loss: 0.1573
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9533 - loss: 0.1197 - val_accuracy: 0.9467 - val_loss: 0.1549
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9576 - loss: 0.1163 - val_accuracy: 0.9483 - val_loss: 0.1452
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9542 - loss: 0.1288 - val_accuracy: 0.9433 - val_loss: 0.1501
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9597 - loss: 0.1081 - val_accuracy: 0.9417 - val_loss: 0.1377
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.9572 - loss: 0.1175 - val_accuracy: 0.9400 - val_loss: 0.1467
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9628 - loss: 0.0902 - val_accuracy: 0.9400 - val_loss: 0.1451
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9525 - loss: 0.1167 - val_accuracy: 0.9450 - val_loss: 0.1395
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.9682 - loss: 0.0905 - val_accuracy: 0.9517 - val_loss: 0.1413
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.9643 - loss: 0.0984 - val_accuracy: 0.9500 - val_loss: 0.1436
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9608 - loss: 0.0932 - val_accuracy: 0.9517 - val_loss: 0.1467
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.9623 - loss: 0.0917 - val_accuracy: 0.9483 - val_loss: 0.1458

# %%
model.load_weights('best_checkpoint.weights.h5')
eval_result = model.evaluate(val_ds)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9547 - loss: 0.1337
# [test loss, test accuracy]: [0.14133526384830475, 0.9516666531562805]

# %% [markdown]
# ## Fine-tuning last 3 convolutional layers and classification head together
#
# We will go ahead and train our classification head.

# %% [markdown]
# Now we have our classification layers trained, let's start to unfreeze some top layers of the convolutional base to fine tune the weights.
# We will fine-tune the last 3 convolutional layers, which means that all layers up until `block4_pool` should be frozen, and the layers
# `block5_conv1`, `block5_conv2` and `block5_conv3` should be trainable.
#
# Why not fine-tune more layers? Why not fine-tune the entire convolutional base? We could. However, we need to consider that:
#
# * Earlier layers in the convolutional base encode more generic, reusable features, while layers higher up encode more specialized features. It is
# more useful to fine-tune the more specialized features, as these are the ones that need to be repurposed on our new problem. There would
# be fast-decreasing returns in fine-tuning lower layers.
# * The more parameters we are training, the more we are at risk of overfitting. The convolutional base has 15M parameters, so it would be
# risky to attempt to train it on our small dataset.
#
# Thus, in our situation, it is a good strategy to only fine-tune the top 2 to 3 layers in the convolutional base.
#
# Let's set this up, we will unfreeze our `base_model`,
# and then freeze individual layers inside of it, except the last 3 layers.
#
# Do a model ``summary()`` and you will see now that the number of trainable weights are now 7,079,424 (around 7 millions), much less than previously, because all the layers are frozen except the last 3 layers.

# %%
base_model.trainable = True
# Change numver of models
for layer in base_model.layers[:-6]:
    layer.trainable = False

# %% [markdown]
# Let us examine model summary again. We can see now that we have more trainable weights 7,342,593 compared to previously 263,169.

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 128, 128)  │          0 │ input_layer_1[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 128, 128,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 4, 4, 512) │ 14,714,688 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        513 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,663,045 (113.16 MB)
#  Trainable params: 7,342,593 (28.01 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)
#  Optimizer params: 14,685,188 (56.02 MB)

# %% [markdown]
# As you are training a much larger model and want to readapt the pretrained weights, it is important to use a lower learning rate at this stage as we do not want to make too drastic changes to the weights in the convolutional layers under fine-tuning.

# %%
finetune_learning_rate = base_learning_rate / 10.

model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=finetune_learning_rate),
              metrics=["accuracy"])

model.fit(
    train_ds,
    epochs=15,
    validation_data=val_ds,
    callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 108ms/step - accuracy: 0.9934 - loss: 0.0218 - val_accuracy: 0.9467 - val_loss: 0.1650
# Epoch 2/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 96ms/step - accuracy: 0.9876 - loss: 0.0428 - val_accuracy: 0.9417 - val_loss: 0.2114
# Epoch 3/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.9877 - loss: 0.0380 - val_accuracy: 0.9500 - val_loss: 0.2067
# Epoch 4/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - accuracy: 0.9955 - loss: 0.0144 - val_accuracy: 0.8783 - val_loss: 0.9686
# Epoch 5/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.9880 - loss: 0.0587 - val_accuracy: 0.9600 - val_loss: 0.2757
# Epoch 6/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9938 - loss: 0.0475 - val_accuracy: 0.9500 - val_loss: 0.3055
# Epoch 7/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 1.0000 - loss: 3.7649e-04 - val_accuracy: 0.9517 - val_loss: 0.3495
# Epoch 8/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step - accuracy: 0.9983 - loss: 0.0040 - val_accuracy: 0.9483 - val_loss: 0.3066
# Epoch 9/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 95ms/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 0.9433 - val_loss: 0.7566
# Epoch 10/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 96ms/step - accuracy: 0.9902 - loss: 0.0335 - val_accuracy: 0.9317 - val_loss: 0.4843
# Epoch 11/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9801 - loss: 0.0751 - val_accuracy: 0.9483 - val_loss: 0.1552
# Epoch 12/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 95ms/step - accuracy: 0.9971 - loss: 0.0156 - val_accuracy: 0.9483 - val_loss: 0.1913
# Epoch 13/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.9960 - loss: 0.0132 - val_accuracy: 0.9533 - val_loss: 0.1730
# Epoch 14/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 95ms/step - accuracy: 0.9984 - loss: 0.0053 - val_accuracy: 0.9417 - val_loss: 0.2114
# Epoch 15/15
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 95ms/step - accuracy: 1.0000 - loss: 3.8050e-04 - val_accuracy: 0.9467 - val_loss: 0.2282

# %%
model.load_weights('best_checkpoint.weights.h5')
eval_result = model.evaluate(val_ds)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9789 - loss: 0.0941
# [test loss, test accuracy]: [0.16012005507946014, 0.9666666388511658]

# %% [markdown]
# **Exercise:**
#
# 1. Is our fine-tuned model performing better or worse?
# 2. Try to unfreeze less/more layers and see if the model performance improves.
